# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from keras import regularizers
# Out:
# Using TensorFlow backend.

# %%
data = pd.read_excel("/home/prajith_v/coding/datasets/FMC Avg SKU Rates 2017.xlsx")

# %%
xls = pd.ExcelFile('/home/prajith_v/coding/datasets/FMC Avg SKU Rates 2017.xlsx')
data1 = pd.read_excel(xls, '2019')
data2 = pd.read_excel(xls, '2018')
data3 = pd.read_excel(xls,'2017')

# %%
df = pd.DataFrame(np.arange(12).reshape(3,4),
                      columns=['A', 'B', 'C', 'D'])

# %%
data1
# Out:
#     Unnamed: 0  Unnamed: 1              Unnamed: 2           Unnamed: 3  \
# 0          NaN         NaN                   SKU's  Average Yearly Rate
# 1          NaN         NaN         Beans (Cow Pea)                28.82
# 2          NaN         NaN           Beans(French)              59.7933
# 3          NaN         NaN            Beans(Local)               46.375
# 4          NaN         NaN                Beetroot              21.3083
# 5          NaN         NaN            Bitter Gourd              39.7917
# 6          NaN         NaN             BottleGourd              12.1817
# 7          NaN         NaN  Brinjal (Bottle Black)               31.675
# 8          NaN         NaN    Brinjal (Long Green)                 21.3
# 9          NaN         NaN         Cabbage (Local)               13.835
# 10         NaN         NaN        Capsicum (Green)              33.9517
# 11         NaN         NaN           Carrot(Local)               25.905
# ...

# %%
data2
# Out:
#     Unnamed: 0  Unnamed: 1              Unnamed: 2         Unnamed: 3  \
# 0          NaN         NaN                   SKU's  Min FMC Assurance
# 1          NaN         NaN         Beans (Cow Pea)            14.5795
# 2          NaN         NaN           Beans(French)             17.797
# 3          NaN         NaN            Beans(Local)               14.3
# 4          NaN         NaN                Beetroot             8.3915
# 5          NaN         NaN            Bitter Gourd             12.051
# 6          NaN         NaN             BottleGourd              6.578
# 7          NaN         NaN  Brinjal (Bottle Black)            11.2385
# 8          NaN         NaN    Brinjal (Long Green)             10.153
# 9          NaN         NaN         Cabbage (Local)             3.7895
# 10         NaN         NaN        Capsicum (Green)            13.4485
# 11         NaN         NaN           Carrot(Local)             13.793
# ...

# %%
data3
# Out:
#     Unnamed: 0  Unnamed: 1              Unnamed: 2           Unnamed: 3  \
# 0          NaN         NaN                   SKU's  Average Yearly Rate
# 1          NaN         NaN         Beans (Cow Pea)                31.51
# 2          NaN         NaN           Beans(French)                 46.4
# 3          NaN         NaN            Beans(Local)                32.49
# 4          NaN         NaN                Beetroot                22.94
# 5          NaN         NaN            Bitter Gourd                23.91
# 6          NaN         NaN             BottleGourd                14.88
# 7          NaN         NaN  Brinjal (Bottle Black)                31.78
# 8          NaN         NaN    Brinjal (Long Green)                24.96
# 9          NaN         NaN         Cabbage (Local)                12.14
# 10         NaN         NaN        Capsicum (Green)                26.11
# 11         NaN         NaN           Carrot(Local)                34.98
# ...

# %%
stri = "Unnamed: "
dic1 = {}
for i in range(6):
    nu = i+4
    s = stri+str(nu)
    print(data1[s].values[0])
    name = "2019 "+data1[s].values[0]
    dic1[name] = data1[s].values[1:]
dic1
# Out:
# Jan
# Feb
# Mar
# Apr
# May
# June
# {'2019 Jan': array([24.4, 25.85, 22.89, 20.64, 36.38, 12.17, 35.81, 26.42, 8.56, 33.07,
#         19.38, 25.21, 21.62, 10.06, 13.43, 14.19, 14.56, 12.7, 24.15, 14.5,
#         34.58, 11.05, 21.32, 17.04], dtype=object),
#  '2019 Feb': array([17.14, 28.35, 27.32, 20.17, 31.93, 8.01, 21.67, 13.26, 9.59, 28.78,
#         12.67, 27.48, 24.34, 11.47, 14.52, 13.95, 12.54, 13.41, 22.77,
#         12.61, 32.77, 11.98, 12.06, 7.83], dtype=object),
#  '2019 Mar': array([33.46, 56.88, 49.4, 18.91, 37.65, 17.14, 33.4, 21.9, 16.98, 38.17,
#         17.31, 35.66, 32.78, 15.87, 18.53, 13.7, 14.34, 11.56, 24.01,
#         12.53, 36.66, 16.19, 13.95, 10.08], dtype=object),
#  '2019 Apr': array([40.16, 77.51, 60.18, 21.51, 38.46, 12.79, 32.36, 20.39, 15.19,
#         35.61, 26.5, 41.22, 39.91, 25.86, 18.46, 15.48, 11.7, 13.99, 12.32,
#         14.94, 35.46, 17.22, 18.31, 22.14], dtype=object),
# ...

# %%
#data2 = data2.rename(columns={"2018":"Unnamed: 8"})
data2
# Out:
#     Unnamed: 0  Unnamed: 1              Unnamed: 2         Unnamed: 3  \
# 0          NaN         NaN                   SKU's  Min FMC Assurance
# 1          NaN         NaN         Beans (Cow Pea)            14.5795
# 2          NaN         NaN           Beans(French)             17.797
# 3          NaN         NaN            Beans(Local)               14.3
# 4          NaN         NaN                Beetroot             8.3915
# 5          NaN         NaN            Bitter Gourd             12.051
# 6          NaN         NaN             BottleGourd              6.578
# 7          NaN         NaN  Brinjal (Bottle Black)            11.2385
# 8          NaN         NaN    Brinjal (Long Green)             10.153
# 9          NaN         NaN         Cabbage (Local)             3.7895
# 10         NaN         NaN        Capsicum (Green)            13.4485
# 11         NaN         NaN           Carrot(Local)             13.793
# ...

# %%
stri = "Unnamed: "
dic2 = {}
for i in range(12):
    nu = i+5
    s = stri+str(nu)
    print(data2[s].values[0])
    name = "2018 "+data2[s].values[0]
    dic2[name] = data2[s].values[1:]
dic2
# Out:
# Jan
# Feb
# Mar
# Apr
# May
# June
# July
# Aug
# Sept
# Oct
# Nov
# Dec
# {'2018 Jan': array([20.15, 11.68, 7.58, 8.53, 11.39, 7.61, 15.22, 14.16, 5.64, 16.81,
#         2.03, 16.59, 4.46, 6.2, 8.88, 7.37, 11.12, 4.53, 10.3, 5.27, 11.78,
#         7.91, 3.34, 3.04], dtype=object),
#  '2018 Feb': array([14.67, 17.41, 13.44, 5.5, 8.86, 4.94, 11.61, 6.68, 3.3, 11.29,
#         11.9, 9.93, 12.99, 5.84, 11.01, 10.89, 9.54, 5.1, 13.79, 5.26,
#         16.78, 8.05, 3.57, 2.69], dtype=object),
#  '2018 Mar': array([20.36, 25.16, 20.38, 6.58, 10.9, 7.49, 10.44, 7.4, 3.38, 13.1,
#         14.66, 12.32, 12.48, 9.84, 16.17, 16.64, 13.01, 6.76, 18.96, 8.71,
#         22.86, 8.35, 5.39, 4.04], dtype=object),
#  '2018 Apr': array([30.74, 31.32, 22.71, 7.31, 15.6, 7.65, 11.88, 9.12, 4.73, 12.42,
#         11.98, 13.65, 10.51, 15.43, 17.17, 9.95, 11.71, 11.45, 16.64, 9.45,
#         24.67, 10.01, 7.73, 6.92], dtype=object),
# ...

# %%
data3
# Out:
#     Unnamed: 0  Unnamed: 1              Unnamed: 2           Unnamed: 3  \
# 0          NaN         NaN                   SKU's  Average Yearly Rate
# 1          NaN         NaN         Beans (Cow Pea)                31.51
# 2          NaN         NaN           Beans(French)                 46.4
# 3          NaN         NaN            Beans(Local)                32.49
# 4          NaN         NaN                Beetroot                22.94
# 5          NaN         NaN            Bitter Gourd                23.91
# 6          NaN         NaN             BottleGourd                14.88
# 7          NaN         NaN  Brinjal (Bottle Black)                31.78
# 8          NaN         NaN    Brinjal (Long Green)                24.96
# 9          NaN         NaN         Cabbage (Local)                12.14
# 10         NaN         NaN        Capsicum (Green)                26.11
# 11         NaN         NaN           Carrot(Local)                34.98
# ...

# %%
stri = "Unnamed: "
dic3= {}
for i in range(12):
    nu = i+4
    s = stri+str(nu)
    print(data3[s].values[0])
    name = "2017 "+data3[s].values[0]
    dic3[name] = data3[s].values[1:]
dic3
# Out:
# Jan
# Feb
# Mar
# Apr
# May
# June
# July
# Aug
# Sept
# Oct
# Nov
# Dec
# {'2017 Jan': array([31.56, 32.67, 27.05, 7.74, 28, 10.86, 10.47, 16.38, 4.08, 21.82,
#         9.51, 22.83, 24.8, 7.89, 25.29, 23.31, 18.27, 21.22, 35, 13.72,
#         24.8, 16.87, 9.1, 9.57], dtype=object),
#  '2017 Feb': array([34.7, 37.69, 33.27, 8.27, 34.56, 13.73, 15.97, 15.94, 4.24, 20.34,
#         13.46, 28.71, 21.91, 10.33, 18.02, 5.2, 14.57, 18.01, 41.5, 7.52,
#         32.76, 20.57, 19.21, 20.69], dtype=object),
#  '2017 Mar': array([35.19, 49.98, 43.11, 20.19, 37.24, 17.06, 29.37, 24.72, 9.48, 23.8,
#         22.13, 32, 21, 14.31, 14.42, 10.69, 17.45, 11.3, 25, 8.53, 29.26,
#         27.13, 19.4, 19.4], dtype=object),
#  '2017 Apr': array([34.96, 80.83, 63.98, 29.6, 40.24, 12.94, 45.37, 38.48, 14.93,
#         17.87, 42.1, 46.82, 26.67, 35.46, 19.55, 11.33, 14.48, 21.37, 19,
#         17, 20.08, 27.05, 8.31, 8.25], dtype=object),
# ...

# %%
dic = {}
dic.update({**dic3,**dic2,**dic1})

# %%
dic
# Out:
# {'2017 Jan': array([31.56, 32.67, 27.05, 7.74, 28, 10.86, 10.47, 16.38, 4.08, 21.82,
#         9.51, 22.83, 24.8, 7.89, 25.29, 23.31, 18.27, 21.22, 35, 13.72,
#         24.8, 16.87, 9.1, 9.57], dtype=object),
#  '2017 Feb': array([34.7, 37.69, 33.27, 8.27, 34.56, 13.73, 15.97, 15.94, 4.24, 20.34,
#         13.46, 28.71, 21.91, 10.33, 18.02, 5.2, 14.57, 18.01, 41.5, 7.52,
#         32.76, 20.57, 19.21, 20.69], dtype=object),
#  '2017 Mar': array([35.19, 49.98, 43.11, 20.19, 37.24, 17.06, 29.37, 24.72, 9.48, 23.8,
#         22.13, 32, 21, 14.31, 14.42, 10.69, 17.45, 11.3, 25, 8.53, 29.26,
#         27.13, 19.4, 19.4], dtype=object),
#  '2017 Apr': array([34.96, 80.83, 63.98, 29.6, 40.24, 12.94, 45.37, 38.48, 14.93,
#         17.87, 42.1, 46.82, 26.67, 35.46, 19.55, 11.33, 14.48, 21.37, 19,
#         17, 20.08, 27.05, 8.31, 8.25], dtype=object),
#  '2017 May': array([34.92, 91.37, 64.55, 29.81, 40.29, 11.32, 36.84, 29.79, 19.54,
# ...

# %%
data_final = pd.DataFrame(data=dic)

# %%
data_final
# Out:
#    2017 Apr 2017 Aug 2017 Dec 2017 Feb 2017 Jan 2017 July 2017 June 2017 Mar  \
# 0     34.96    33.56     24.5     34.7    31.56     28.67      27.5    35.19
# 1     80.83    47.63    26.46    37.69    32.67     46.94     69.29    49.98
# 2     63.98    30.75    17.43    33.27    27.05        32     42.97    43.11
# 3      29.6    24.38    17.87     8.27     7.74     20.93     21.02    20.19
# 4     40.24    20.49    14.53    34.56       28     26.99     37.75    37.24
# 5     12.94    14.41    11.96    13.73    10.86     13.16     10.04    17.06
# 6     45.37     45.3    17.43    15.97    10.47     37.58     39.28    29.37
# 7     38.48    24.79    14.63    15.94    16.38     34.24     22.85    24.72
# 8     14.93    10.79    12.77     4.24     4.08      7.21     10.81     9.48
# 9     17.87    31.01    25.25    20.34    21.82     30.43     23.43     23.8
# 10     42.1     39.1    48.35    13.46     9.51      47.7     54.29    22.13
# ...

# %%
def plot_series(time, series, format="-", start=0, end=None):
    plt.plot(time[start:end], series[start:end], format)
    plt.xlabel("Time")
    plt.ylabel("Value")
    plt.grid(True)

# %%
names = data1["Unnamed: 2"].values[1:]
names = np.array(names)

# %%
dic
# Out:
# {'2017 Jan': array([31.56, 32.67, 27.05, 7.74, 28, 10.86, 10.47, 16.38, 4.08, 21.82,
#         9.51, 22.83, 24.8, 7.89, 25.29, 23.31, 18.27, 21.22, 35, 13.72,
#         24.8, 16.87, 9.1, 9.57], dtype=object),
#  '2017 Feb': array([34.7, 37.69, 33.27, 8.27, 34.56, 13.73, 15.97, 15.94, 4.24, 20.34,
#         13.46, 28.71, 21.91, 10.33, 18.02, 5.2, 14.57, 18.01, 41.5, 7.52,
#         32.76, 20.57, 19.21, 20.69], dtype=object),
#  '2017 Mar': array([35.19, 49.98, 43.11, 20.19, 37.24, 17.06, 29.37, 24.72, 9.48, 23.8,
#         22.13, 32, 21, 14.31, 14.42, 10.69, 17.45, 11.3, 25, 8.53, 29.26,
#         27.13, 19.4, 19.4], dtype=object),
#  '2017 Apr': array([34.96, 80.83, 63.98, 29.6, 40.24, 12.94, 45.37, 38.48, 14.93,
#         17.87, 42.1, 46.82, 26.67, 35.46, 19.55, 11.33, 14.48, 21.37, 19,
#         17, 20.08, 27.05, 8.31, 8.25], dtype=object),
#  '2017 May': array([34.92, 91.37, 64.55, 29.81, 40.29, 11.32, 36.84, 29.79, 19.54,
# ...

# %%
mon = ['Jan','Feb','Mar','Apr','May','June','July','Aug','Sept','Oct','Nov','Dec']
mon1 = []
num =[]
for i in range(12):
    name = mon[i]+" "+str(2017)
    mon1.append(name)
    c = np.array(dic[name])
    num.append(c)
for i in range(12):
    name = mon[i]+" "+str(2018)
    mon1.append(name)
    c = np.array(dic[name])
    num.append(c)
for i in range(6):
    name = mon[i]+" "+str(2019)
    mon1.append(name)
    c = np.array(dic[name])
    num.append(c)
name = np.array(name)
print(num)
# Out:
# [array([31.56, 32.67, 27.05, 7.74, 28, 10.86, 10.47, 16.38, 4.08, 21.82,
#        9.51, 22.83, 24.8, 7.89, 25.29, 23.31, 18.27, 21.22, 35, 13.72,
#        24.8, 16.87, 9.1, 9.57], dtype=object), array([34.7, 37.69, 33.27, 8.27, 34.56, 13.73, 15.97, 15.94, 4.24, 20.34,
#        13.46, 28.71, 21.91, 10.33, 18.02, 5.2, 14.57, 18.01, 41.5, 7.52,
#        32.76, 20.57, 19.21, 20.69], dtype=object), array([35.19, 49.98, 43.11, 20.19, 37.24, 17.06, 29.37, 24.72, 9.48, 23.8,
#        22.13, 32, 21, 14.31, 14.42, 10.69, 17.45, 11.3, 25, 8.53, 29.26,
#        27.13, 19.4, 19.4], dtype=object), array([34.96, 80.83, 63.98, 29.6, 40.24, 12.94, 45.37, 38.48, 14.93,
#        17.87, 42.1, 46.82, 26.67, 35.46, 19.55, 11.33, 14.48, 21.37, 19,
#        17, 20.08, 27.05, 8.31, 8.25], dtype=object), array([34.92, 91.37, 64.55, 29.81, 40.29, 11.32, 36.84, 29.79, 19.54,
#        19.71, 51.6, 38.08, 37.43, 37.04, 26.7, 17.78, 12.36, 23.37, 15.08,
# ...

# %%
num = np.asarray(num).astype(np.float32)

# %%
num.shape
# Out:
# (30, 24)

# %%
plt.figure(figsize=(25,9))
for i in range(24):
    plot_series(mon1,num[:,i])
plt.legend(names)

# %%
plt.figure(figsize=(20,9))
plot_series(mon1,num[:,0])
plt.legend("beans_cow_pea")

# %%
time_train = mon1[:-10]
x_train = num[:-10,0]
time_valid = mon1[-10:]
x_valid = num[-10:,0]

# %%
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    
    dataset = tf.data.Dataset.from_tensor_slices(series)
    dataset = dataset.window(window_size + 1, shift=1, drop_remainder=True)
    dataset = dataset.flat_map(lambda window: window.batch(window_size + 1))
    dataset = dataset.shuffle(shuffle_buffer).map(lambda window: (window[:-1], window[-1]))
    dataset = dataset.batch(batch_size).prefetch(1)
    return dataset

# %%
c = windowed_dataset(x_train,12,32,30)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(10, input_shape=[12], activation="relu"), 
    tf.keras.layers.Dense(50, activation="relu"), 
    tf.keras.layers.Dense(1)
])

model.compile(loss="mae", optimizer=tf.keras.optimizers.SGD(lr=0.000002, momentum=0.9))
history = model.fit(c,epochs=2000,verbose=1)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 182ms/step - loss: 25.6758
# Epoch 2/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 25.6720
# Epoch 3/2000
# 1/1 [==============================] - 0s 25ms/step - loss: 25.6646
# Epoch 4/2000
# 1/1 [==============================] - 0s 19ms/step - loss: 25.6541
# Epoch 5/2000
# 1/1 [==============================] - 0s 26ms/step - loss: 25.6408
# Epoch 6/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 25.6250
# Epoch 7/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 25.6070
# Epoch 8/2000
# 1/1 [==============================] - 0s 24ms/step - loss: 25.5869
# Epoch 9/2000
# 1/1 [==============================] - 0s 22ms/step - loss: 25.5649
# Epoch 10/2000
# 1/1 [==============================] - 0s 23ms/step - loss: 25.5414
# Epoch 11/2000
# 1/1 [==============================] - 0s 20ms/step - loss: 25.5163
# Epoch 12/2000
# ...

# %%
forecast = x_train[-12:]
for i in range(10):
    h = model.predict(forecast[i:i+12][np.newaxis])
    print(h,x_valid[i])
    forecast = np.append(forecast,h)
    print(forecast.shape)
# Out:
# [[16.92923]] 24.62
# (13,)
# [[17.236992]] 27.11
# (14,)
# [[18.125069]] 18.83
# (15,)
# [[14.629543]] 18.65
# (16,)
# [[14.513285]] 24.4
# (17,)
# [[14.417597]] 17.14
# (18,)
# [[14.347799]] 33.46
# (19,)
# [[14.514568]] 40.16
# (20,)
# [[13.117971]] 29.63
# (21,)
# [[13.1988735]] 28.13
# (22,)

# %%
plot_series(mon1[-10:],x_valid)
plot_series(mon1[-10:],forecast[-10:])

# %%
plt.figure(figsize=(24,9))
plot_series(mon1,num[:,1])
plt.legend("beans_french")

# %%
time_train = mon1[:-5]
x_train = num[:-5,0]
time_valid = mon1[-5:]
x_valid = num[-5:,0]

# %%
c = windowed_dataset(x_train,12,6,15)
model = tf.keras.models.Sequential([
  tf.keras.layers.Lambda(lambda x: tf.expand_dims(x, axis=-1),
                      input_shape=[None]),
    tf.keras.layers.Conv1D(filters=64, kernel_size=4,
                      strides=2, padding="causal",
                      activation="relu"),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(30,activation='relu'),
    tf.keras.layers.Dense(10,activation='relu'),
    tf.keras.layers.Dense(1),
    tf.keras.layers.Lambda(lambda x: x * 100.0)
])

model.compile(loss=tf.keras.losses.Huber(), optimizer=tf.keras.optimizers.SGD(lr=0.000002, momentum=0.9))
history = model.fit(c,epochs=2000,verbose=1)
# Out:
# Epoch 1/2000
# 3/3 [==============================] - 4s 1s/step - loss: 14.2063
# Epoch 2/2000
# 3/3 [==============================] - 0s 13ms/step - loss: 12.1170
# Epoch 3/2000
# 3/3 [==============================] - 0s 19ms/step - loss: 9.3895
# Epoch 4/2000
# 3/3 [==============================] - 0s 17ms/step - loss: 6.7332
# Epoch 5/2000
# 3/3 [==============================] - 0s 19ms/step - loss: 4.3656
# Epoch 6/2000
# 3/3 [==============================] - 0s 17ms/step - loss: 2.9458
# Epoch 7/2000
# 3/3 [==============================] - 0s 17ms/step - loss: 2.7816
# Epoch 8/2000
# 3/3 [==============================] - 0s 17ms/step - loss: 3.5308
# Epoch 9/2000
# 3/3 [==============================] - 0s 19ms/step - loss: 4.8033
# Epoch 10/2000
# 3/3 [==============================] - 0s 20ms/step - loss: 3.3183
# Epoch 11/2000
# 3/3 [==============================] - 0s 16ms/step - loss: 3.6656
# Epoch 12/2000
# ...

# %%
forecast = x_train[-6:]
print(x_train)
print(forecast)
print(num[:,0])
for i in range(5):
    h = model.predict(forecast[i:i+6][np.newaxis])
    print(h,x_valid[i])
    forecast = np.append(forecast,h)
    print(forecast.shape)
# Out:
# [31.56 34.7  35.19 34.96 34.92 27.5  28.67 33.56 32.92 31.28 28.29 24.5
#  20.15 14.67 20.36 30.74 29.93 21.06 21.86 26.91 24.62 27.11 18.83 18.65
#  24.4 ]
# [26.91 24.62 27.11 18.83 18.65 24.4 ]
# [31.56 34.7  35.19 34.96 34.92 27.5  28.67 33.56 32.92 31.28 28.29 24.5
#  20.15 14.67 20.36 30.74 29.93 21.06 21.86 26.91 24.62 27.11 18.83 18.65
#  24.4  17.14 33.46 40.16 29.63 28.13]
# [[28.971365]] 17.14
# (7,)
# [[25.680716]] 33.46
# (8,)
# [[17.096977]] 40.16
# (9,)
# [[17.770164]] 29.63
# (10,)
# [[25.06264]] 28.13
# (11,)

# %%
plot_series(mon1[-5:],x_valid)
plot_series(mon1[-5:],forecast[-5:])

# %%
forecast = []
for time in range(30-12):
    print(num[time:time+12,0])
    print((model.predict(num[time:time + 12,0][np.newaxis])),num[time+12,0])
    forecast.append((model.predict(num[time:time + 12,0][np.newaxis])))
print(forecast)

#forecast = forecast[60-3:]
results = np.array(forecast)[:, 0, 0]


plt.figure(figsize=(10, 6))
#print(num[:,1].shape,results.shape)
plot_series(mon1[12:], num[12:,0])
plot_series(mon1[12:], results)
# Out:
# [31.56 34.7  35.19 34.96 34.92 27.5  28.67 33.56 32.92 31.28 28.29 24.5 ]
# [[27.356619]] 20.15
# [34.7  35.19 34.96 34.92 27.5  28.67 33.56 32.92 31.28 28.29 24.5  20.15]
# [[24.308487]] 14.67
# [35.19 34.96 34.92 27.5  28.67 33.56 32.92 31.28 28.29 24.5  20.15 14.67]
# [[26.034605]] 20.36
# [34.96 34.92 27.5  28.67 33.56 32.92 31.28 28.29 24.5  20.15 14.67 20.36]
# [[34.91863]] 30.74
# [34.92 27.5  28.67 33.56 32.92 31.28 28.29 24.5  20.15 14.67 20.36 30.74]
# [[38.423367]] 29.93
# [27.5  28.67 33.56 32.92 31.28 28.29 24.5  20.15 14.67 20.36 30.74 29.93]
# [[37.45445]] 21.06
# [28.67 33.56 32.92 31.28 28.29 24.5  20.15 14.67 20.36 30.74 29.93 21.06]
# [[34.99378]] 21.86
# [33.56 32.92 31.28 28.29 24.5  20.15 14.67 20.36 30.74 29.93 21.06 21.86]
# [[38.514965]] 26.91
# [32.92 31.28 28.29 24.5  20.15 14.67 20.36 30.74 29.93 21.06 21.86 26.91]
# [[41.988503]] 24.62
# [31.28 28.29 24.5  20.15 14.67 20.36 30.74 29.93 21.06 21.86 26.91 24.62]
# [[39.343525]] 27.11
# ...

# %%
num.shape
# Out:
# (30, 24)

# %%
data_final["vegetables"] = names

# %%
data_final
# Out:
#    2017 Apr 2017 Aug 2017 Dec 2017 Feb 2017 Jan 2017 July 2017 June 2017 Mar  \
# 0     34.96    33.56     24.5     34.7    31.56     28.67      27.5    35.19
# 1     80.83    47.63    26.46    37.69    32.67     46.94     69.29    49.98
# 2     63.98    30.75    17.43    33.27    27.05        32     42.97    43.11
# 3      29.6    24.38    17.87     8.27     7.74     20.93     21.02    20.19
# 4     40.24    20.49    14.53    34.56       28     26.99     37.75    37.24
# 5     12.94    14.41    11.96    13.73    10.86     13.16     10.04    17.06
# 6     45.37     45.3    17.43    15.97    10.47     37.58     39.28    29.37
# 7     38.48    24.79    14.63    15.94    16.38     34.24     22.85    24.72
# 8     14.93    10.79    12.77     4.24     4.08      7.21     10.81     9.48
# 9     17.87    31.01    25.25    20.34    21.82     30.43     23.43     23.8
# 10     42.1     39.1    48.35    13.46     9.51      47.7     54.29    22.13
# ...

# %%
trial = data_final.sort_values(by = "2017 Jan",ascending=True)

# %%
value = trial["2017 Jan"].values[:]
na = trial["vegetables"].values[:]

# %%
value
# Out:
# array([4.08, 7.74, 7.89, 9.1, 9.51, 9.57, 10.47, 10.86, 13.72, 16.38,
#        16.87, 18.27, 21.22, 21.82, 22.83, 23.31, 24.8, 24.8, 25.29, 27.05,
#        28, 31.56, 32.67, 35], dtype=object)

# %%
na
# Out:
# array(['Cabbage (Local)', 'Beetroot', 'Chow Chow', 'Tomato (Hybrid-Std)',
#        'Carrot(Local)', 'Tomato (Local)', 'Brinjal (Bottle Black)',
#        'BottleGourd', 'Raddish', 'Brinjal (Long Green)', 'Snake gourd',
#        'Ivy Gourd', 'Knol Khol', 'Capsicum (Green)', 'Chilli(Bajji)',
#        'Cucumber(Indian)', 'Chilli(Long)', 'Ridge Gourd',
#        'Cucumber(English)', 'Beans(Local)', 'Bitter Gourd',
#        'Beans (Cow Pea)', 'Beans(French)', "Lady's Finger"], dtype=object)

# %%
jan2017 = {}
less = {}
more = {}
for i in range(5):
    str1 = na[i]
    str2 = na[-(i+1)]
    less[str1] = value[i]
    more[str2] = value[-(i+1)]
jan2017["less"] = less
jan2017["more"] = more

# %%
jan2017
feb2017
mar2017
apr2017
may2017
june2017
july2017
aug2017
sep2017
oct2017
nov2017
dec2017
# Out:
# {'less': {'Cucumber(Indian)': 5.53,
#   'Raddish': 7.42,
#   'Chow Chow': 7.67,
#   'Tomato (Local)': 7.94,
#   'Knol Khol': 7.99},
#  'more': {'Carrot(Local)': 48.35,
#   'Beans(French)': 26.46,
#   'Capsicum (Green)': 25.25,
#   'Beans (Cow Pea)': 24.5,
#   'Beetroot': 17.87}}

# %%
s = "2019 June"
trial = data_final.sort_values(by = s,ascending=True)

value = trial[s].values[:]
na = trial["vegetables"].values[:]

june2019 = {}
less = {}
more = {}
for i in range(5):
    str1 = na[i]
    str2 = na[-(i+1)]
    less[str1] = value[i]
    more[str2] = value[-(i+1)]
june2019["less"] = less
june2019["more"] = more

# %%
jan2019
feb2019
mar2019
apr2019
may2019
june2019
# Out:
# {'less': {'Ivy Gourd': 11.9,
#   'BottleGourd': 12.6,
#   'Snake gourd': 13.66,
#   'Cabbage (Local)': 15.74,
#   "Lady's Finger": 16.53},
#  'more': {'Beans(French)': 87.58,
#   'Beans(Local)': 64.61,
#   'Bitter Gourd': 47.69,
#   'Chilli(Bajji)': 45.09,
#   'Carrot(Local)': 44.13}}

# %%
jan2018
feb2018
mar2018
apr2018
may2018
june2018
july2018
aug2018
sep2018
oct2018
nov2018
dec2018
# Out:
# {'less': {'Cabbage (Local)': 5.41,
#   'Knol Khol': 7.81,
#   'Snake gourd': 8.9,
#   'Tomato (Local)': 9.06,
#   'Chow Chow': 9.29},
#  'more': {'Carrot(Local)': 29.32,
#   'Bitter Gourd': 23.17,
#   'Ridge Gourd': 21.55,
#   'Beans(French)': 21.44,
#   'Beans(Local)': 19.48}}

# %%
dic2 = {}
dic2.update({**jan2017,**jan2018,**jan2019,**feb2017,**feb2018,**feb2019,**mar2017,**mar2018,**mar2019,**apr2017,**apr2018,**apr2019,**may2017,**may2018,**may2019,**june2017,**june2018,**june2019,**july2017,**july2018,**aug2017,**aug2018,**sep2017,**sep2018,**oct2017,**oct2018,**nov2017,**nov2018,**dec2017,**dec2018})

# %%
data_full2 = pd.DataFrame({"jan2017":jan2017,"jan2018":jan2018,"jan2019":jan2019,"feb2017":feb2017,"feb2018":feb2018,"feb2019":feb2019,"mar2017":mar2017,"mar2018":mar2018,"mar2019":mar2019,"apr2017":apr2017,"apr2018":apr2018,"apr2019":apr2019,"may2017":may2017,"may2018":may2018,"may2019":may2019,"june2017":june2017,"june2018":june2018,"june2019":june2019,"july2017":july2017,"july2018":july2018,"aug2017":aug2017,"aug2018":aug2018,"sep2017":sep2017,"sep2018":sep2018,"oct2017":oct2017,"oct2018":oct2018,"nov2017":nov2017,"nov2018":nov2018,"dec2017":dec2017,"dec2018": dec2018})

# %%
data_full2.to_excel("/home/prajith_v/coding/jupyter_notebook/agriculture/ananlyzed_data.xlsx")

# %%
a = data_full2.loc["less","jan2017"]
# Out:
# {'Cabbage (Local)': 4.08,
#  'Beetroot': 7.74,
#  'Chow Chow': 7.89,
#  'Tomato (Hybrid-Std)': 9.1,
#  'Carrot(Local)': 9.51}

# %%
b = data_full2.loc["less","jan2018"]
# Out:
# {'Carrot(Local)': 2.03,
#  'Tomato (Local)': 3.04,
#  'Tomato (Hybrid-Std)': 3.34,
#  'Chilli(Long)': 4.46,
#  'Knol Khol': 4.53}

# %%
c = data_full2.loc["less","jan2019"]
print(c)
# Out:
# {'Cabbage (Local)': 8.56, 'Chow Chow': 10.06, 'Snake gourd': 11.05, 'BottleGourd': 12.17, 'Knol Khol': 12.7}

# %%
n=[]
for j in c.items():
    n.append(j)
jan = n
n=[]
for j in c.items():
    n.append(j)
jan.append(n)
n=[]
for j in c.items():
    n.append(j)
jan.append(n)
print(type(jan))
# Out:
# <class 'list'>

# %%
jan
# Out:
# [('Cabbage (Local)', 8.56),
#  ('Chow Chow', 10.06),
#  ('Snake gourd', 11.05),
#  ('BottleGourd', 12.17),
#  ('Knol Khol', 12.7),
#  [('Cabbage (Local)', 8.56),
#   ('Chow Chow', 10.06),
#   ('Snake gourd', 11.05),
#   ('BottleGourd', 12.17),
#   ('Knol Khol', 12.7)],
#  [('Cabbage (Local)', 8.56),
#   ('Chow Chow', 10.06),
#   ('Snake gourd', 11.05),
#   ('BottleGourd', 12.17),
#   ('Knol Khol', 12.7)]]

# %%
a = data_full2.loc["less","jan2017"]
b = data_full2.loc["less","jan2018"]
c = data_full2.loc["less","jan2019"]

jan_low=[]
n1=[]
for j in a.items():
    n1.append([j])

n2=[]
for j in b.items():
    n2.append([j])

n3=[]
for j in c.items():
    n3.append([j])
# Out:
# [['Cabbage (Local)', 4]]
# [['Cabbage (Local)', 4], ['Beetroot', 7]]
# [['Cabbage (Local)', 4], ['Beetroot', 7], ['Chow Chow', 7]]
# [['Cabbage (Local)', 4], ['Beetroot', 7], ['Chow Chow', 7], ['Tomato (Hybrid-Std)', 9]]
# [['Cabbage (Local)', 4], ['Beetroot', 7], ['Chow Chow', 7], ['Tomato (Hybrid-Std)', 9], ['Carrot(Local)', 9]]
# <class 'float'>
# [[('Carrot(Local)', 2.03)]]
# <class 'float'>
# [[('Carrot(Local)', 2.03)], [('Tomato (Local)', 3.04)]]
# <class 'float'>
# [[('Carrot(Local)', 2.03)], [('Tomato (Local)', 3.04)], [('Tomato (Hybrid-Std)', 3.34)]]
# <class 'float'>
# [[('Carrot(Local)', 2.03)], [('Tomato (Local)', 3.04)], [('Tomato (Hybrid-Std)', 3.34)], [('Chilli(Long)', 4.46)]]
# <class 'float'>
# [[('Carrot(Local)', 2.03)], [('Tomato (Local)', 3.04)], [('Tomato (Hybrid-Std)', 3.34)], [('Chilli(Long)', 4.46)], [('Knol Khol', 4.53)]]

# %%
low_data = pd.DataFrame({"jan_low":[n1,n2,n3]})
low_data
# Out:
#                                              jan_low
# 0  [[(Cabbage (Local), 4.08)], [(Beetroot, 7.74)]...
# 1  [[(Carrot(Local), 2.03)], [(Tomato (Local), 3....
# 2  [[(Cabbage (Local), 8.56)], [(Chow Chow, 10.06...

# %%
a = data_full2.loc["less","dec2017"]
b = data_full2.loc["less","dec2018"]
#c = data_full2.loc["less","dec2019"]

dec_low=[]
n1=[]
for j in a.items():
    n1.append([j])

n2=[]
for j in b.items():
    n2.append([j])

n3=np.nan
#for j in c.items():
#    n3.append([j])


low_data["dec_low"] = [n1,n2,n3]
low_data
# Out:
#                                              jan_low  \
# 0  [[(Cabbage (Local), 4.08)], [(Beetroot, 7.74)]...
# 1  [[(Carrot(Local), 2.03)], [(Tomato (Local), 3....
# 2  [[(Cabbage (Local), 8.56)], [(Chow Chow, 10.06...
#
#                                              feb_low  \
# 0  [[(Cabbage (Local), 4.24)], [(Cucumber(Indian)...
# 1  [[(Tomato (Local), 2.69)], [(Cabbage (Local), ...
# 2  [[(Tomato (Local), 7.83)], [(BottleGourd, 8.01...
#
#                                              mar_low  \
# 0  [[(Raddish, 8.53)], [(Cabbage (Local), 9.48)],...
# 1  [[(Cabbage (Local), 3.38)], [(Tomato (Local), ...
# 2  [[(Tomato (Local), 10.08)], [(Knol Khol, 11.56...
#
#                                              apr_low  \
# 0  [[(Tomato (Local), 8.25)], [(Tomato (Hybrid-St...
# 1  [[(Cabbage (Local), 4.73)], [(Tomato (Local), ...
# 2  [[(Ivy Gourd, 11.7)], [(Lady's Finger, 12.32)]...
#
#                                              may_low  \
# ...

# %%
low_data.to_excel("/home/prajith_v/coding/jupyter_notebook/agriculture/low_data.xlsx")

# %%
a = data_full2.loc["more","jan2017"]
b = data_full2.loc["more","jan2018"]
c = data_full2.loc["more","jan2019"]

dec_low=[]
n1=[]
for j in a.items():
    n1.append([j])

n2=[]
for j in b.items():
    n2.append([j])

n3=[]
for j in c.items():
    n3.append([j])

# %%
high_data = pd.DataFrame({"jan_high":[n1,n2,n3]})
high_data
# Out:
#                                             jan_high
# 0  [[(Lady's Finger, 35)], [(Beans(French), 32.67...
# 1  [[(Beans (Cow Pea), 20.15)], [(Capsicum (Green...
# 2  [[(Bitter Gourd, 36.38)], [(Brinjal (Bottle Bl...

# %%
a = data_full2.loc["more","dec2017"]
b = data_full2.loc["more","dec2018"]
#c = data_full2.loc["more","dec2019"]

dec_low=[]
n1=[]
for j in a.items():
    n1.append([j])

n2=[]
for j in b.items():
    n2.append([j])

n3=np.nan
#for j in c.items():
#    n3.append([j])

high_data["dec_high"] = [n1,n2,n3]
high_data
# Out:
#                                             jan_high  \
# 0  [[(Lady's Finger, 35)], [(Beans(French), 32.67...
# 1  [[(Beans (Cow Pea), 20.15)], [(Capsicum (Green...
# 2  [[(Bitter Gourd, 36.38)], [(Brinjal (Bottle Bl...
#
#                                             feb_high  \
# 0  [[(Lady's Finger, 41.5)], [(Beans(French), 37....
# 1  [[(Beans(French), 17.41)], [(Ridge Gourd, 16.7...
# 2  [[(Ridge Gourd, 32.77)], [(Bitter Gourd, 31.93...
#
#                                             mar_high  \
# 0  [[(Beans(French), 49.98)], [(Beans(Local), 43....
# 1  [[(Beans(French), 25.16)], [(Ridge Gourd, 22.8...
# 2  [[(Beans(French), 56.88)], [(Beans(Local), 49....
#
#                                             apr_high  \
# 0  [[(Beans(French), 80.83)], [(Beans(Local), 63....
# 1  [[(Beans(French), 31.32)], [(Beans (Cow Pea), ...
# 2  [[(Beans(French), 77.51)], [(Beans(Local), 60....
#
#                                             may_high  \
# ...

# %%
high_data.to_excel("/home/prajith_v/coding/jupyter_notebook/agriculture/high_data.xlsx")

# %%
c = pd.read_excel("/home/prajith_v/coding/jupyter_notebook/agriculture/high_data.xlsx")

# %%
c["apr_high"].values[:]
# Out:
# array(["[[('Beans(French)', 80.83)], [('Beans(Local)', 63.98)], [('Chilli(Bajji)', 46.82)], [('Brinjal (Bottle Black)', 45.37)], [('Carrot(Local)', 42.1)]]",
#        "[[('Beans(French)', 31.32)], [('Beans (Cow Pea)', 30.74)], [('Ridge Gourd', 24.67)], [('Beans(Local)', 22.71)], [('Cucumber(English)', 17.17)]]",
#        "[[('Beans(French)', 77.51)], [('Beans(Local)', 60.18)], [('Chilli(Bajji)', 41.22)], [('Beans (Cow Pea)', 40.16)], [('Chilli(Long)', 39.91)]]"],
#       dtype=object)

# %%
c = c.set_index([["2017","2018","2019"]])

# %%
c.to_excel("/home/prajith_v/coding/jupyter_notebook/agriculture/high_data.xlsx")

# %%
c = pd.read_excel("/home/prajith_v/coding/jupyter_notebook/agriculture/low_data.xlsx")

# %%
c = c.set_index([["2017","2018","2019"]])

# %%
c.to_excel("/home/prajith_v/coding/jupyter_notebook/agriculture/low_data.xlsx")

# %%
d = pd.DataFrame(c)
# Out:
#                                              jan_low  \
# 0  [[('Cabbage (Local)', 4.08)], [('Beetroot', 7....
# 1  [[('Carrot(Local)', 2.03)], [('Tomato (Local)'...
# 2  [[('Cabbage (Local)', 8.56)], [('Chow Chow', 1...
#
#                                              feb_low  \
# 0  [[('Cabbage (Local)', 4.24)], [('Cucumber(Indi...
# 1  [[('Tomato (Local)', 2.69)], [('Cabbage (Local...
# 2  [[('Tomato (Local)', 7.83)], [('BottleGourd', ...
#
#                                              mar_low  \
# 0  [[('Raddish', 8.53)], [('Cabbage (Local)', 9.4...
# 1  [[('Cabbage (Local)', 3.38)], [('Tomato (Local...
# 2  [[('Tomato (Local)', 10.08)], [('Knol Khol', 1...
#
#                                              apr_low  \
# 0  [[('Tomato (Local)', 8.25)], [('Tomato (Hybrid...
# 1  [[('Cabbage (Local)', 4.73)], [('Tomato (Local...
# 2  [[('Ivy Gourd', 11.7)], [("Lady's Finger", 12....
#
#                                              may_low  \
# ...
